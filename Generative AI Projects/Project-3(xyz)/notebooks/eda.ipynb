# %% [markdown]
# # Healthcare AI EDA
#
# Run `python scripts/prepare_demo_data.py` before this notebook.

# %%
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

root = Path('..')
df = pd.read_csv(root / 'data/raw/symptom_patient_records.csv')
df.head()

# %%
df.isna().sum(), df['disease'].value_counts()

# %%
numeric = df.select_dtypes('number')
plt.figure(figsize=(10, 7))
sns.heatmap(numeric.corr(), cmap='vlag', center=0)
plt.title('Feature Correlation')
